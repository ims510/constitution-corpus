# %% [markdown]
# Ouvrir le corpus avec panda

# %%
# combine moldovan_news.csv and romanian_news.csv into a single file

import pandas as pd

csv_files = ['/Users/madalina/Documents/M1TAL/outils_trait_corpus/constitution-corpus/data/clean/moldovan_news.csv', '/Users/madalina/Documents/M1TAL/outils_trait_corpus/constitution-corpus/data/clean/romanian_news.csv']
df_csv_append = pd.DataFrame()
 
# append the CSV files
for file in csv_files:
    df = pd.read_csv(file)
    df_csv_append = df_csv_append.append(df, ignore_index=True)
 
dataset = df_csv_append
dataset
# Out:
# /var/folders/mg/9cp9yr5152g510k_59bb0gsh0000gn/T/ipykernel_89809/1520760148.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csv_append = df_csv_append.append(df, ignore_index=True)
# /var/folders/mg/9cp9yr5152g510k_59bb0gsh0000gn/T/ipykernel_89809/1520760148.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csv_append = df_csv_append.append(df, ignore_index=True)
#           id    category                                               text
# 0     741234  stiri-auto  Grație unei colaborări cu Centrul auto $NE$ al...
# 1     742681       sport    Astfel , $NE$ $NE$ a învins formația din cap...
# 2     742651   societate    19.04.2024 Pentru informații suplimentare co...
# 3     742671    economie    Este vorba de un volum de 12.800 MWh sau 20 ...
# ...

# %%
import pandas as pd

data = pd.read_csv("/Users/madalina/Documents/M1TAL/outils_trait_corpus/constitution-corpus/data/clean/romanian_news.csv")
data
# Out:
#           id    category                                               text
# 0   22329753     externe  Secretarul $NE$ de stat a $NE$ , Janet Yellen ...
# 1   22329745     politic  Cătălin Cîrstoiu a vorbit , la Antena 3 CNN , ...
# 2   22329472     politic  „ Vă spun ceva , vom câştiga alegerile . Vom s...
# 3   22329360    economic  $NE$ $NE$ $NE$ , din cadrul grupului Intrakat ...
# 4   22329172    economic  $NE$ Europeană a aprobat reintroducerea unei s...
# 5   22329170      social  ISU $NE$ a transmis că mina marină a fost ridi...
# 6   22329096  tehnologie  Începând de anul trecut , un nou tip de dronă ...
# 7   22329136     externe  Yellen a declarat că $NE$ $NE$ , Joe Biden , n...
# 8   22329133     externe  Afirmaţia a fost făcută $NE$ , la $NE$ , în ca...
# 9   22328934     politic  Redăm mai jos interviul integral : $NE$ : Poli...
# 10  22328902     externe  Propunerea lui Trump este ca $NE$ să cedeze Ru...
# ...

# %%
# train_dataset = train_dataset.to_pandas()
dataset = Dataset.from_pandas(dataset)
dataset
# Out:
# Dataset({
#     features: ['id', 'category', 'text'],
#     num_rows: 65
# })

# %%
dataset[0]
# Out:
# {'id': 741234,
#  'category': 'stiri-auto',
#  'text': 'Grație unei colaborări cu Centrul auto $NE$ al DAAC Hermes , $NE$ vă dezvăluie tot ce trebuie să știți despre acest automobil modern . Cu un motor puternic și o sumedenie de sisteme de asistență pentru $NE$ , $NE$ se remarcă prin confort și design elegant . $NE$ ne împărtășește impresiile sale , subliniind cum fiecare $NE$ și fiecare inovație fac din $NE$ alegerea perfectă pentru iubitorii de tehnologie și stil . Acesta este doar începutul unei călătorii prin lumea $NE$ alături de $NE$ . $NE$ cu noi pentru mai multe recenzii din gama de modele $NE$ , care continuă să ne încînte prin inovație , stil și tehnologie .  '}
